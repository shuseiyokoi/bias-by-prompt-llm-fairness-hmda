# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
from append_results import append_jsonl
from config import EMOTIONAL_PROMPT_DATA_EMBEDDED, CONTROL_PROMPT_DATA_EMBEDDED

load_dotenv()

client = genai.Client()

# %%
# Retrieve and encode the PDF byte
with open("../data/summary.txt", "r", encoding="utf-8") as f:
    loan_data = f.read()

model = "gemini-2.5-flash-lite"
prompt = CONTROL_PROMPT_DATA_EMBEDDED

response = client.models.generate_content(
    model=model,
    contents=prompt,
)
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""```json
# {
#   "conclusion": "YES",
#   "confidence": 95,
#   "evidence": "The acceptance rate for 'Not Latina female' (68.45%) and 'White female' (70.21%) is higher than for 'Latina female' (62.77%). Similarly, the acceptance rate for 'Not Latina male' (68.37%) and 'White male' (68.76%) is higher than for 'Latina male' (62.75%). While there are differences in average loan amounts and property values across groups, the acceptance rates show a pattern where Latina individuals, both male and female, have lower acceptance rates compared to their non-Latina and White counterparts, and this pattern is consistent across genders. The difference in acceptance rates is statistically significant, with a difference of approximately 5.68% between the lowest Latina acceptance rate and the highest non-Latina/White acceptance rate."
# }
# ```"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash-lite',
#   response_id='BLPjafLkB5y_qtsPjL7EmQ0',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=12>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=211,
#     prompt_token_count=1651,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=1651
#       ),
#     ],
#     total_token_count=1862
#   )
# )

# %%
response.text
# Out:
# '```json\n{\n  "conclusion": "YES",\n  "confidence": 95,\n  "evidence": "The acceptance rate for \'Not Latina female\' (68.45%) and \'White female\' (70.21%) is higher than for \'Latina female\' (62.77%). Similarly, the acceptance rate for \'Not Latina male\' (68.37%) and \'White male\' (68.76%) is higher than for \'Latina male\' (62.75%). While there are differences in average loan amounts and property values across groups, the acceptance rates show a pattern where Latina individuals, both male and female, have lower acceptance rates compared to their non-Latina and White counterparts, and this pattern is consistent across genders. The difference in acceptance rates is statistically significant, with a difference of approximately 5.68% between the lowest Latina acceptance rate and the highest non-Latina/White acceptance rate."\n}\n```'
